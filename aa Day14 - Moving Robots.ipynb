# %%
#Annette Alca
#Advent of Code 2024
#Day 14 
#Robots

# %%
import numpy as np

# %%
fileN = 'Day14 input.txt'

file = open(fileN,'r')
lines = file.read().splitlines()
lines[:10]
# Out:
# ['p=99,12 v=19,18',
#  'p=90,98 v=47,-52',
#  'p=86,3 v=82,-13',
#  'p=13,8 v=-67,-47',
#  'p=36,45 v=28,65',
#  'p=71,35 v=-8,-62',
#  'p=75,8 v=-30,-21',
#  'p=3,46 v=-38,-96',
#  'p=1,89 v=78,18',
#  'p=47,59 v=-63,99']

# %%
#change into dictionary
#first part

print ('robots = {}')

for i in range(len(lines)):
    l = lines[i]
    l = l.replace('p=','[[')
    l = l.replace(' v=','],[')
    l = l + ']]'
    print(f'robots[{i}]={l}')

print('robots')
#copy paste below
# Out:
# robots = {}
# robots[0]=[[99,12],[19,18]]
# robots[1]=[[90,98],[47,-52]]
# robots[2]=[[86,3],[82,-13]]
# robots[3]=[[13,8],[-67,-47]]
# robots[4]=[[36,45],[28,65]]
# robots[5]=[[71,35],[-8,-62]]
# robots[6]=[[75,8],[-30,-21]]
# robots[7]=[[3,46],[-38,-96]]
# robots[8]=[[1,89],[78,18]]
# robots[9]=[[47,59],[-63,99]]
# robots[10]=[[92,78],[68,48]]
# robots[11]=[[42,31],[78,94]]
# robots[12]=[[75,29],[9,83]]
# robots[13]=[[46,12],[-29,48]]
# robots[14]=[[80,16],[-70,33]]
# robots[15]=[[18,66],[57,-97]]
# robots[16]=[[60,12],[89,-90]]
# robots[17]=[[21,36],[-41,-78]]
# robots[18]=[[75,53],[52,-62]]
# robots[19]=[[18,79],[45,51]]
# robots[20]=[[20,29],[63,-97]]
# robots[21]=[[22,68],[23,1]]
# robots[22]=[[6,67],[-24,-44]]
# robots[23]=[[44,35],[-54,29]]
# robots[24]=[[33,80],[28,-56]]
# robots[25]=[[48,78],[55,-22]]
# robots[26]=[[88,79],[99,69]]
# robots[27]=[[12,96],[-50,-59]]
# robots[28]=[[6,57],[80,61]]
# robots[29]=[[98,31],[-77,14]]
# robots[30]=[[91,65],[-13,20]]
# ...

# %%
#change to dictionary
#secodn part, copy paste above

robots = {}
robots[0]=[[99,12],[19,18]]
robots[1]=[[90,98],[47,-52]]
robots[2]=[[86,3],[82,-13]]
robots[3]=[[13,8],[-67,-47]]
robots[4]=[[36,45],[28,65]]
robots[5]=[[71,35],[-8,-62]]
robots[6]=[[75,8],[-30,-21]]
robots[7]=[[3,46],[-38,-96]]
robots[8]=[[1,89],[78,18]]
robots[9]=[[47,59],[-63,99]]
robots[10]=[[92,78],[68,48]]
robots[11]=[[42,31],[78,94]]
robots[12]=[[75,29],[9,83]]
robots[13]=[[46,12],[-29,48]]
robots[14]=[[80,16],[-70,33]]
robots[15]=[[18,66],[57,-97]]
robots[16]=[[60,12],[89,-90]]
robots[17]=[[21,36],[-41,-78]]
robots[18]=[[75,53],[52,-62]]
robots[19]=[[18,79],[45,51]]
robots[20]=[[20,29],[63,-97]]
robots[21]=[[22,68],[23,1]]
robots[22]=[[6,67],[-24,-44]]
robots[23]=[[44,35],[-54,29]]
robots[24]=[[33,80],[28,-56]]
robots[25]=[[48,78],[55,-22]]
robots[26]=[[88,79],[99,69]]
robots[27]=[[12,96],[-50,-59]]
robots[28]=[[6,57],[80,61]]
robots[29]=[[98,31],[-77,14]]
robots[30]=[[91,65],[-13,20]]
robots[31]=[[52,53],[-85,41]]
robots[32]=[[94,94],[-15,5]]
robots[33]=[[69,75],[-41,-11]]
robots[34]=[[98,77],[71,-54]]
robots[35]=[[23,47],[-61,-27]]
robots[36]=[[32,74],[-11,96]]
robots[37]=[[22,87],[-5,-75]]
robots[38]=[[65,22],[26,71]]
robots[39]=[[1,67],[13,69]]
robots[40]=[[32,96],[-90,-94]]
robots[41]=[[17,17],[-5,71]]
robots[42]=[[57,85],[-92,28]]
robots[43]=[[52,32],[-41,69]]
robots[44]=[[13,85],[-43,-83]]
robots[45]=[[51,39],[-38,32]]
robots[46]=[[64,17],[91,82]]
robots[47]=[[97,86],[-69,-70]]
robots[48]=[[98,94],[46,-21]]
robots[49]=[[43,31],[61,-24]]
robots[50]=[[42,58],[-51,-42]]
robots[51]=[[5,46],[-4,91]]
robots[52]=[[65,52],[10,50]]
robots[53]=[[23,6],[-42,29]]
robots[54]=[[54,25],[4,44]]
robots[55]=[[5,19],[-77,-74]]
robots[56]=[[44,77],[-23,-26]]
robots[57]=[[10,70],[6,-72]]
robots[58]=[[38,101],[-50,-36]]
robots[59]=[[9,49],[35,72]]
robots[60]=[[64,14],[77,-78]]
robots[61]=[[21,2],[-67,-6]]
robots[62]=[[34,97],[-73,-37]]
robots[63]=[[77,13],[-30,60]]
robots[64]=[[50,40],[83,-58]]
robots[65]=[[99,85],[-59,-87]]
robots[66]=[[65,0],[-76,-48]]
robots[67]=[[44,94],[-45,34]]
robots[68]=[[5,59],[92,35]]
robots[69]=[[73,100],[93,-71]]
robots[70]=[[50,20],[-74,-97]]
robots[71]=[[9,33],[-10,-89]]
robots[72]=[[54,49],[-46,99]]
robots[73]=[[99,100],[92,51]]
robots[74]=[[84,94],[-53,-45]]
robots[75]=[[92,13],[-61,69]]
robots[76]=[[19,52],[56,-12]]
robots[77]=[[20,52],[-38,-90]]
robots[78]=[[98,12],[99,-22]]
robots[79]=[[46,23],[95,-32]]
robots[80]=[[84,100],[-70,70]]
robots[81]=[[19,69],[58,-52]]
robots[82]=[[77,67],[-51,31]]
robots[83]=[[11,6],[18,-67]]
robots[84]=[[11,22],[-50,-82]]
robots[85]=[[73,43],[25,79]]
robots[86]=[[60,16],[-58,-36]]
robots[87]=[[86,18],[-88,71]]
robots[88]=[[21,50],[-50,-88]]
robots[89]=[[17,20],[-65,-54]]
robots[90]=[[38,26],[67,71]]
robots[91]=[[22,60],[-46,15]]
robots[92]=[[81,46],[-39,16]]
robots[93]=[[25,98],[22,-41]]
robots[94]=[[9,72],[-94,8]]
robots[95]=[[82,59],[-46,-34]]
robots[96]=[[71,41],[-23,45]]
robots[97]=[[74,1],[-70,32]]
robots[98]=[[96,17],[-37,95]]
robots[99]=[[39,45],[-6,-23]]
robots[100]=[[46,4],[61,55]]
robots[101]=[[41,100],[-35,-10]]
robots[102]=[[65,75],[-1,-26]]
robots[103]=[[8,21],[7,-32]]
robots[104]=[[43,71],[-12,73]]
robots[105]=[[85,67],[58,-41]]
robots[106]=[[73,7],[31,-89]]
robots[107]=[[85,71],[-93,-72]]
robots[108]=[[54,83],[-46,-75]]
robots[109]=[[13,66],[-24,-98]]
robots[110]=[[67,13],[21,-21]]
robots[111]=[[1,33],[24,-66]]
robots[112]=[[71,27],[54,-78]]
robots[113]=[[69,86],[42,35]]
robots[114]=[[17,28],[-83,94]]
robots[115]=[[92,19],[25,-68]]
robots[116]=[[92,84],[-31,16]]
robots[117]=[[32,26],[-6,54]]
robots[118]=[[20,97],[-16,36]]
robots[119]=[[1,102],[13,9]]
robots[120]=[[59,26],[-68,91]]
robots[121]=[[92,44],[-20,30]]
robots[122]=[[16,45],[-83,34]]
robots[123]=[[30,69],[-75,-46]]
robots[124]=[[51,64],[-73,68]]
robots[125]=[[53,29],[-57,-61]]
robots[126]=[[14,100],[-15,86]]
robots[127]=[[80,41],[-20,-81]]
robots[128]=[[5,92],[-60,1]]
robots[129]=[[91,10],[-49,98]]
robots[130]=[[0,62],[-79,9]]
robots[131]=[[40,1],[3,-70]]
robots[132]=[[81,32],[-53,41]]
robots[133]=[[53,18],[-46,94]]
robots[134]=[[69,96],[-95,-82]]
robots[135]=[[32,92],[-69,-30]]
robots[136]=[[73,83],[-59,-65]]
robots[137]=[[74,67],[-8,-99]]
robots[138]=[[71,45],[-58,60]]
robots[139]=[[35,29],[-51,-92]]
robots[140]=[[68,15],[-92,-55]]
robots[141]=[[74,3],[26,30]]
robots[142]=[[67,25],[-58,22]]
robots[143]=[[31,46],[-73,-92]]
robots[144]=[[29,69],[45,23]]
robots[145]=[[48,78],[-23,-29]]
robots[146]=[[41,13],[-45,-78]]
robots[147]=[[57,8],[-3,26]]
robots[148]=[[45,53],[45,4]]
robots[149]=[[37,23],[-62,41]]
robots[150]=[[41,90],[-35,55]]
robots[151]=[[88,96],[53,-71]]
robots[152]=[[38,15],[-90,71]]
robots[153]=[[62,20],[4,-88]]
robots[154]=[[64,19],[15,-85]]
robots[155]=[[96,61],[10,81]]
robots[156]=[[19,81],[57,-45]]
robots[157]=[[53,11],[67,44]]
robots[158]=[[51,83],[66,85]]
robots[159]=[[29,76],[-84,-26]]
robots[160]=[[63,23],[-13,14]]
robots[161]=[[23,51],[-18,-52]]
robots[162]=[[23,41],[73,-55]]
robots[163]=[[99,75],[-32,-14]]
robots[164]=[[68,20],[79,45]]
robots[165]=[[27,74],[45,42]]
robots[166]=[[55,96],[47,-73]]
robots[167]=[[87,29],[-93,22]]
robots[168]=[[20,76],[-49,88]]
robots[169]=[[11,78],[-67,-41]]
robots[170]=[[31,78],[-12,-99]]
robots[171]=[[21,49],[64,9]]
robots[172]=[[56,45],[10,-4]]
robots[173]=[[67,97],[-59,92]]
robots[174]=[[96,58],[-49,96]]
robots[175]=[[36,51],[-68,8]]
robots[176]=[[18,10],[-79,-60]]
robots[177]=[[25,7],[47,-55]]
robots[178]=[[12,101],[40,-52]]
robots[179]=[[83,57],[-42,-38]]
robots[180]=[[62,89],[77,20]]
robots[181]=[[8,49],[51,-54]]
robots[182]=[[12,98],[-20,53]]
robots[183]=[[47,89],[35,68]]
robots[184]=[[46,16],[89,6]]
robots[185]=[[72,34],[37,45]]
robots[186]=[[61,31],[49,76]]
robots[187]=[[42,98],[64,17]]
robots[188]=[[27,41],[71,27]]
robots[189]=[[50,8],[-1,-63]]
robots[190]=[[97,5],[-56,9]]
robots[191]=[[41,58],[5,-38]]
robots[192]=[[66,101],[-64,13]]
robots[193]=[[67,95],[-40,18]]
robots[194]=[[94,41],[-37,73]]
robots[195]=[[89,102],[-4,2]]
robots[196]=[[44,51],[-84,65]]
robots[197]=[[9,89],[29,89]]
robots[198]=[[28,29],[5,29]]
robots[199]=[[76,4],[-89,8]]
robots[200]=[[75,93],[-75,89]]
robots[201]=[[38,6],[-73,-2]]
robots[202]=[[19,1],[-95,-6]]
robots[203]=[[61,76],[-69,23]]
robots[204]=[[6,27],[64,-24]]
robots[205]=[[97,76],[47,28]]
robots[206]=[[62,86],[50,-61]]
robots[207]=[[85,50],[-93,-92]]
robots[208]=[[10,76],[-83,31]]
robots[209]=[[58,42],[52,-81]]
robots[210]=[[47,42],[16,38]]
robots[211]=[[3,17],[-66,52]]
robots[212]=[[58,84],[-59,-36]]
robots[213]=[[91,76],[20,-68]]
robots[214]=[[9,62],[-10,-23]]
robots[215]=[[45,99],[-85,-2]]
robots[216]=[[0,8],[-77,17]]
robots[217]=[[53,70],[-41,-23]]
robots[218]=[[32,96],[6,89]]
robots[219]=[[67,33],[26,37]]
robots[220]=[[94,86],[47,47]]
robots[221]=[[26,74],[-39,12]]
robots[222]=[[19,15],[-55,16]]
robots[223]=[[60,76],[93,-98]]
robots[224]=[[44,71],[-49,-38]]
robots[225]=[[35,77],[-1,-7]]
robots[226]=[[68,98],[32,89]]
robots[227]=[[10,54],[-23,-24]]
robots[228]=[[63,10],[-77,50]]
robots[229]=[[75,61],[71,80]]
robots[230]=[[35,78],[-5,-55]]
robots[231]=[[74,23],[15,-45]]
robots[232]=[[10,68],[52,-34]]
robots[233]=[[45,43],[8,-67]]
robots[234]=[[12,76],[24,-75]]
robots[235]=[[62,73],[-86,77]]
robots[236]=[[9,82],[-38,-64]]
robots[237]=[[1,95],[25,-64]]
robots[238]=[[67,30],[-69,-20]]
robots[239]=[[92,25],[-79,75]]
robots[240]=[[42,19],[-46,-78]]
robots[241]=[[3,98],[35,-83]]
robots[242]=[[89,102],[53,90]]
robots[243]=[[25,10],[-5,37]]
robots[244]=[[46,0],[-74,29]]
robots[245]=[[12,40],[-79,92]]
robots[246]=[[13,21],[-56,-44]]
robots[247]=[[63,49],[77,-27]]
robots[248]=[[3,12],[83,-67]]
robots[249]=[[48,42],[72,-62]]
robots[250]=[[37,74],[-46,16]]
robots[251]=[[25,75],[51,-26]]
robots[252]=[[84,35],[81,-43]]
robots[253]=[[38,40],[-63,19]]
robots[254]=[[77,13],[-64,-48]]
robots[255]=[[95,13],[-82,-44]]
robots[256]=[[81,41],[-19,-81]]
robots[257]=[[33,81],[-64,41]]
robots[258]=[[69,75],[65,35]]
robots[259]=[[30,76],[45,39]]
robots[260]=[[48,72],[-29,39]]
robots[261]=[[74,10],[78,-61]]
robots[262]=[[70,17],[9,52]]
robots[263]=[[11,67],[46,-87]]
robots[264]=[[35,72],[-11,-46]]
robots[265]=[[86,37],[-82,60]]
robots[266]=[[99,24],[-91,56]]
robots[267]=[[92,46],[-54,-23]]
robots[268]=[[93,12],[76,-9]]
robots[269]=[[92,43],[-97,-75]]
robots[270]=[[3,72],[10,-79]]
robots[271]=[[13,83],[13,8]]
robots[272]=[[78,80],[3,-60]]
robots[273]=[[81,41],[84,-73]]
robots[274]=[[93,9],[-25,36]]
robots[275]=[[78,96],[20,-37]]
robots[276]=[[40,50],[-78,59]]
robots[277]=[[66,21],[85,78]]
robots[278]=[[37,67],[56,53]]
robots[279]=[[49,62],[-91,-63]]
robots[280]=[[59,54],[60,-69]]
robots[281]=[[57,81],[77,39]]
robots[282]=[[51,79],[-19,-11]]
robots[283]=[[65,27],[74,95]]
robots[284]=[[33,56],[44,-27]]
robots[285]=[[7,43],[80,38]]
robots[286]=[[11,19],[36,-88]]
robots[287]=[[27,15],[-95,44]]
robots[288]=[[2,76],[-15,-53]]
robots[289]=[[90,40],[-14,56]]
robots[290]=[[93,52],[30,-92]]
robots[291]=[[31,42],[56,-16]]
robots[292]=[[86,64],[-25,-51]]
robots[293]=[[97,81],[-76,-76]]
robots[294]=[[11,36],[35,-77]]
robots[295]=[[9,94],[-10,-48]]
robots[296]=[[35,3],[68,-6]]
robots[297]=[[10,84],[69,58]]
robots[298]=[[12,17],[18,71]]
robots[299]=[[61,62],[77,-4]]
robots[300]=[[6,93],[29,-82]]
robots[301]=[[91,71],[-49,62]]
robots[302]=[[84,5],[26,-17]]
robots[303]=[[100,1],[-22,-38]]
robots[304]=[[90,27],[-34,-39]]
robots[305]=[[84,21],[-68,-62]]
robots[306]=[[72,10],[-70,63]]
robots[307]=[[83,20],[42,-74]]
robots[308]=[[51,99],[-57,51]]
robots[309]=[[13,56],[-78,76]]
robots[310]=[[21,88],[80,81]]
robots[311]=[[40,97],[76,85]]
robots[312]=[[61,92],[-97,-15]]
robots[313]=[[29,58],[56,-88]]
robots[314]=[[90,0],[-34,-2]]
robots[315]=[[35,46],[-23,-35]]
robots[316]=[[88,49],[82,-67]]
robots[317]=[[83,23],[98,-1]]
robots[318]=[[19,80],[-5,-98]]
robots[319]=[[21,45],[-90,45]]
robots[320]=[[79,3],[-14,-86]]
robots[321]=[[49,37],[27,-54]]
robots[322]=[[95,0],[-93,36]]
robots[323]=[[55,46],[-63,26]]
robots[324]=[[38,78],[-61,-97]]
robots[325]=[[91,61],[-60,-92]]
robots[326]=[[44,15],[-51,75]]
robots[327]=[[82,86],[20,-72]]
robots[328]=[[93,69],[8,-95]]
robots[329]=[[93,59],[-37,50]]
robots[330]=[[73,50],[-84,22]]
robots[331]=[[8,7],[-50,25]]
robots[332]=[[97,46],[-14,22]]
robots[333]=[[43,2],[-96,44]]
robots[334]=[[29,32],[-33,34]]
robots[335]=[[30,64],[-56,-95]]
robots[336]=[[12,65],[-38,54]]
robots[337]=[[64,54],[-12,-54]]
robots[338]=[[32,29],[66,-4]]
robots[339]=[[80,84],[-24,34]]
robots[340]=[[2,93],[53,-87]]
robots[341]=[[77,14],[59,-82]]
robots[342]=[[12,25],[-77,78]]
robots[343]=[[65,74],[76,-61]]
robots[344]=[[93,89],[-26,59]]
robots[345]=[[1,35],[25,-12]]
robots[346]=[[100,26],[1,48]]
robots[347]=[[28,79],[-96,16]]
robots[348]=[[18,1],[-16,2]]
robots[349]=[[42,38],[-39,-31]]
robots[350]=[[35,76],[-76,-93]]
robots[351]=[[28,6],[78,24]]
robots[352]=[[36,33],[-34,-5]]
robots[353]=[[26,73],[-95,-95]]
robots[354]=[[96,22],[-83,-25]]
robots[355]=[[82,74],[-30,-76]]
robots[356]=[[9,98],[46,-52]]
robots[357]=[[80,3],[13,-65]]
robots[358]=[[65,11],[68,-58]]
robots[359]=[[68,57],[-13,57]]
robots[360]=[[91,2],[27,-94]]
robots[361]=[[2,96],[-16,-29]]
robots[362]=[[65,67],[-6,-55]]
robots[363]=[[79,63],[88,-19]]
robots[364]=[[17,12],[-27,52]]
robots[365]=[[10,6],[52,-86]]
robots[366]=[[3,74],[-37,-61]]
robots[367]=[[90,47],[14,68]]
robots[368]=[[77,87],[-59,20]]
robots[369]=[[80,63],[-98,8]]
robots[370]=[[20,27],[-64,10]]
robots[371]=[[93,60],[-54,-38]]
robots[372]=[[93,14],[52,95]]
robots[373]=[[53,79],[-63,-87]]
robots[374]=[[12,21],[-10,-70]]
robots[375]=[[71,62],[76,-19]]
robots[376]=[[77,13],[-3,-48]]
robots[377]=[[51,99],[-46,-36]]
robots[378]=[[58,50],[77,-31]]
robots[379]=[[59,62],[54,43]]
robots[380]=[[66,66],[-86,12]]
robots[381]=[[34,87],[-93,-88]]
robots[382]=[[93,64],[-47,71]]
robots[383]=[[11,5],[1,-67]]
robots[384]=[[54,11],[-80,-13]]
robots[385]=[[74,31],[-30,-85]]
robots[386]=[[25,60],[6,-34]]
robots[387]=[[94,77],[81,73]]
robots[388]=[[62,70],[-41,54]]
robots[389]=[[44,70],[-68,80]]
robots[390]=[[25,78],[42,71]]
robots[391]=[[46,0],[-29,82]]
robots[392]=[[6,4],[9,76]]
robots[393]=[[34,40],[-52,3]]
robots[394]=[[62,23],[2,50]]
robots[395]=[[85,72],[31,27]]
robots[396]=[[85,67],[1,1]]
robots[397]=[[3,37],[-15,-96]]
robots[398]=[[99,29],[-65,15]]
robots[399]=[[65,67],[-22,-99]]
robots[400]=[[72,65],[55,6]]
robots[401]=[[38,97],[56,-52]]
robots[402]=[[16,13],[35,82]]
robots[403]=[[0,7],[-8,-86]]
robots[404]=[[47,4],[33,-14]]
robots[405]=[[50,34],[-26,59]]
robots[406]=[[27,61],[60,81]]
robots[407]=[[100,11],[13,-93]]
robots[408]=[[94,33],[-26,-35]]
robots[409]=[[9,43],[52,68]]
robots[410]=[[23,73],[-1,-50]]
robots[411]=[[76,88],[62,-78]]
robots[412]=[[62,28],[43,3]]
robots[413]=[[95,22],[-80,79]]
robots[414]=[[43,81],[-84,40]]
robots[415]=[[19,10],[85,2]]
robots[416]=[[40,31],[-45,-81]]
robots[417]=[[33,59],[11,-80]]
robots[418]=[[53,66],[27,12]]
robots[419]=[[52,94],[5,24]]
robots[420]=[[3,96],[-71,-33]]
robots[421]=[[18,48],[28,-27]]
robots[422]=[[76,18],[34,-7]]
robots[423]=[[75,73],[93,-53]]
robots[424]=[[48,9],[-12,48]]
robots[425]=[[65,51],[-69,-66]]
robots[426]=[[78,10],[-14,-40]]
robots[427]=[[44,32],[-52,7]]
robots[428]=[[36,20],[-68,48]]
robots[429]=[[4,58],[63,61]]
robots[430]=[[12,62],[-39,-53]]
robots[431]=[[31,36],[56,-85]]
robots[432]=[[14,58],[-51,-61]]
robots[433]=[[86,11],[-76,-17]]
robots[434]=[[45,38],[-79,-1]]
robots[435]=[[60,41],[29,18]]
robots[436]=[[28,8],[-22,-59]]
robots[437]=[[66,47],[-13,72]]
robots[438]=[[91,15],[-31,-55]]
robots[439]=[[69,73],[15,-87]]
robots[440]=[[52,49],[71,-76]]
robots[441]=[[73,69],[-47,-49]]
robots[442]=[[87,7],[-20,-94]]
robots[443]=[[1,0],[-76,40]]
robots[444]=[[96,48],[-14,88]]
robots[445]=[[52,36],[-46,26]]
robots[446]=[[94,48],[3,-39]]
robots[447]=[[36,38],[-71,-93]]
robots[448]=[[64,8],[55,-47]]
robots[449]=[[75,63],[59,-38]]
robots[450]=[[64,97],[15,-94]]
robots[451]=[[63,102],[4,-40]]
robots[452]=[[41,78],[16,-87]]
robots[453]=[[63,82],[58,50]]
robots[454]=[[32,24],[48,42]]
robots[455]=[[57,69],[-35,31]]
robots[456]=[[73,26],[-2,-28]]
robots[457]=[[31,89],[28,32]]
robots[458]=[[82,93],[-14,62]]
robots[459]=[[61,87],[-12,-26]]
robots[460]=[[58,36],[-72,-13]]
robots[461]=[[80,49],[-59,15]]
robots[462]=[[34,10],[72,40]]
robots[463]=[[4,82],[41,16]]
robots[464]=[[46,12],[5,82]]
robots[465]=[[81,17],[75,-36]]
robots[466]=[[69,12],[99,90]]
robots[467]=[[98,16],[-55,-24]]
robots[468]=[[49,39],[38,-89]]
robots[469]=[[91,1],[92,-32]]
robots[470]=[[91,99],[-48,-33]]
robots[471]=[[16,44],[-60,53]]
robots[472]=[[26,60],[-56,-31]]
robots[473]=[[31,32],[28,-16]]
robots[474]=[[36,40],[33,-47]]
robots[475]=[[60,18],[-97,-51]]
robots[476]=[[5,2],[36,-21]]
robots[477]=[[83,8],[20,-47]]
robots[478]=[[32,40],[-16,-39]]
robots[479]=[[65,11],[-84,11]]
robots[480]=[[58,31],[-80,-5]]
robots[481]=[[96,38],[-42,-65]]
robots[482]=[[40,23],[14,87]]
robots[483]=[[36,81],[67,77]]
robots[484]=[[13,74],[35,96]]
robots[485]=[[6,58],[-36,-64]]
robots[486]=[[73,23],[-53,-5]]
robots[487]=[[22,18],[45,-58]]
robots[488]=[[67,29],[-81,-52]]
robots[489]=[[14,18],[-33,-17]]
robots[490]=[[51,28],[43,-55]]
robots[491]=[[98,11],[-72,95]]
robots[492]=[[80,17],[-53,10]]
robots[493]=[[76,54],[65,-77]]
robots[494]=[[76,98],[-74,66]]
robots[495]=[[12,50],[97,64]]
robots[496]=[[53,27],[67,26]]
robots[497]=[[22,89],[57,-60]]
robots[498]=[[23,34],[40,-43]]
robots[499]=[[35,85],[17,-6]]

print(type(robots))
print(robots[0])
# Out:
# <class 'dict'>
# [[99, 12], [19, 18]]

# %%
#define matrix
maxX = 101
maxY = 103

def wrapMove(p,v):
    '''individual moves'''
    global maxX, maxY
    
    newX = p[0] + v[0]
    newX = newX%maxX #if <0 or over max value
    
    newY= p[1] + v[1]
    newY = newY%maxY #if <0 or over max value
    
    return [newX,newY]

def moveRobot (p,v,times):
    '''p = list of x,y coordinates
    v = list of x,y move after 1 time'''
    global maxX, maxY
    
    currentp = p
    vx,vy = v
    newv = [vx*times,vy*times]

    currentp = wrapMove(currentp,newv)
    return currentp

def centerLines ():
    '''values of x and y which are not part of quadrants'''
    global maxX, maxY
    centerX = maxX//2
    centerY = maxY//2
    return centerX,centerY

def allQuadrants(robotCoords,centerX,centerY):
    '''returns all quadrant values as four separate variables'''
    q1,q2,q3,q4 = 0,0,0,0 #define four empty values
    for x,y in robotCoords:
        if x < centerX and y < centerY: #up left
            q1 +=1
        elif x > centerX and y < centerY: #up right
            q2 +=1
        elif x < centerX and y > centerY: #down left
            q3 +=1
        elif x > centerX and y > centerY: #down right
            q4 +=1
    return q1,q2,q3,q4

# %%
#Part1
times = 100

finalPositions = []
for r in robots:
    p = robots[r][0]
    v = robots[r][1]
    finalp = moveRobot(p,v,times)
    finalPositions.append(finalp)

centerX,centerY = centerLines()
q1,q2,q3,q4 = allQuadrants(finalPositions,centerX,centerY)

print(q1,q2,q3,q4)
print(f'Part1 safety factor: {q1*q2*q3*q4}')
# Out:
# 132 123 98 131
# Part1 safety factor: 208437768

# %%
132 123 98 131
Part1 safety factor: 208437768

# %%
#Part2 functions

def drawMatrix(finalPositions):
    '''draw matrix based on list of coordinates'''
    global maxX, maxY
    for currY in range(maxY):
        line = maxX*' '
        for x,y in finalPositions:
            if y == currY:
                line = line[:x] + '*' + line[x+1:]
        print(line)

# %%
#Part 2
#Use np.std (standard deviation as measure of randomness of robot locations)
#print np.std when it is below 23 (the first few were 29+)

times = 50000
t=1

while t<times:
    finalPositions = []
    t +=1
    for r in robots:
        p = robots[r][0]
        v = robots[r][1]
        finalp = moveRobot(p,v,t)
        finalPositions.append(finalp)
    
    std = np.std(finalPositions)
    
    if std<23:
        print(f'{np.std(finalPositions)} after {t} seconds.')

#at the number of seconds below, std deviation is 20.84 (minimum it reaches)
#Christmas tree is formed
# Out:
# 20.845185895069395 after 7492 seconds.
# 20.845185895069395 after 17895 seconds.
# 20.845185895069395 after 28298 seconds.
# 20.845185895069395 after 38701 seconds.
# 20.845185895069395 after 49104 seconds.

# %%
#drawing after the part 2 answer above
t = 7492

for r in robots:
    p = robots[r][0]
    v = robots[r][1]
    finalp = moveRobot(p,v,t)
    finalPositions.append(finalp)
drawMatrix(finalPositions)
# Out:
#                        *          *       *      *                                     *
#         *          *          *      *            *    *                  * *    **      * *
#   *          *                           *        *                       *                       *
# *         *     *            *          *                                    *         *       *
#   * *        *              *                    *                  *  *                     *
#  *                     *                       *
#         *   *                         *      *      *   *  *        *
#            *                      *                    *  *                                  *   *  *
#     *                  *                   *                   *                      *
#                                                          *      *                   *
# *                        *                 *      *             *
# ...
